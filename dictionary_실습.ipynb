# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeLee-ai/Lee/blob/main/dictionary_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 딕셔너리 생성. 밑의 표를 딕셔널리를 이용해 구현하라.  아이스크림 이름은 딕셔너리의 키이고 남은 수량은 리스트에 담아 딕셔너리 키의 캆으로 사용하라.

# %%
from google.colab import files
uploaded = files.upload()
from IPython.display import Image
Image('파이썬 딕셔너리 문제 1.png')
# Out:
#      <input type="file" id="files-9b1f89fc-8935-4b51-ae14-bb6019bddcdc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b1f89fc-8935-4b51-ae14-bb6019bddcdc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 파이썬 딕셔너리 문제 1.png to 파이썬 딕셔너리 문제 1 (1).png

# %%
import pandas as pd
icecream = {'이름':['Meinna','Pollapo','Ppangppare','Tankboy','Houthunting','Worldcorn'],'희망가격':[1000,1200,1800,1200,1200,1500],}
pdf1 = pd.DataFrame(icecream)
lists = [10,7,6,5,4,3]
pdf1['남은수량'] = lists
print(pdf1)
# Out:
#             이름  희망가격  남은수량
# 0       Meinna  1000    10
# 1      Pollapo  1200     7
# 2   Ppangppare  1800     6
# 3      Tankboy  1200     5
# 4  Houthunting  1200     4
# 5    Worldcorn  1500     3

# %% [markdown]
# # 2. icecream 딕셔너리에서 최소 가격의 아이스크림 이름을 출력하라.

# %%
plt.style.use("default")
jpg_img_arr = mpimg.imread('./img/dic2.png')
plt.axis('off')
imgplot = plt.imshow(jpg_img_arr)
imgplot

# %%
icecream = dict()
icecream['Tankboy'] = 1200
icecream['ppangppare'] = 1800
icecream['Worldcorn'] = 1500
icecream['Melon'] = 1000
minivalue = icecream['ppangppare']
for i in icecream:
  if minivalue>icecream[i]:
    minivalue = icecream[i]
print(i,':',minivalue)
# Out:
# Melon : 1000
